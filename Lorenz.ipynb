# %%
from selenium import webdriver
import pandas as pd
import time

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site='http://lorenzmlwpzgxq736jzseuterytjueszsvznuibanxomlpkyxk6ksoyd.onion'
driver.get(site)

# create empty lists to store the data
company_names = []
company_website = []
Data_Leak = []
Date = []

# extract the data from the current page
name_elements = driver.find_elements("xpath", '//div[@class="panel-heading"]/h3')
for element in name_elements:
    company_names.append(element.text if element.text else 'n/a')

website_elements = driver.find_elements("xpath", "//div[@class='panel-heading']/h5/a[@style]")
for element in website_elements:
    company_website.append(element.text if element.text else 'n/a')

date_elements = driver.find_elements("xpath", '//div[@class="panel panel-primary"]/div/h5[1]')
for element in date_elements:
    Date.append(element.get_attribute('innerText').strip('Posted') if element.get_attribute('innerText').strip('Posted') else 'n/a')

Datas = driver.find_elements("xpath", '//div[@class="panel-body"]/a[1]')
for Data in Datas:
    Data_Leak.append(Data.get_attribute('href') if Data.get_attribute('href') else 'n/a')
        
# create a dataframe with the extracted data
df = pd.DataFrame({
    'Company Names': company_names,
    'Company Link': company_website,
    'Date Posted': Date,
    'Download Data': Data_Leak,
    'DLS website': ['Lorenz'] * len(company_names),
    'DLS link': ['http://lorenzmlwpzgxq736jzseuterytjueszsvznuibanxomlpkyxk6ksoyd.onion'] * len(company_names)
})

print(df)
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_21460\2708375980.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_21460\2708375980.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_21460\2708375980.py:13: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                                         Company Names  \
# 0                                   Moore Engineering
# 1                              Intrasect Technologies
# 2                                           NGS Super
# 3   Joy Cone Co, Joy Baking group, BoDeans Baking,...
# ...

# %%
df
# Out:
#                                         Company Names  \
# 0                                   Moore Engineering
# 1                              Intrasect Technologies
# 2                                           NGS Super
# 3   Joy Cone Co, Joy Baking group, BoDeans Baking,...
# 4             Tarolli, Sundheim, Covell & Tummino LLP
# ..                                                ...
# 56                                           Joy Cone
# 57                                The managementtrust
# 58                                        Windemuller
# 59                                        Multifeeder
# 60                            Commport Communications
#
#                             Company Link            Date Posted  \
# 0   https://www.mooreengineeringinc.com/          Mar 31, 2023.
# 1         https://www.intrasecttech.com/          Mar 29, 2023.
# 2           https://www.ngssuper.com.au/          Mar 25, 2023.
# ...
