# %%
from selenium import webdriver
import pandas as pd
import time
from tqdm import tqdm

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion/'
driver.get(site)

while True:
    # Get current page height
    current_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait for a short time for the content to load
    time.sleep(2)
    
    # Get new page height after scrolling
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Break the loop if the page height remains the same (reached the bottom)
    if new_height == current_height:
        break
        
        
company_names = []        
# extract the data from the current page
name_elements = driver.find_elements("xpath", '//div[@class="card-header"]')
for element in name_elements:
    company_names.append(element.text if element.text else 'n/a')
    
company_names = []  
company_description=[]
Data = []

# extract the data from the current page
name_elements = driver.find_elements("xpath", '//div[@class="card-header"]')
for element in name_elements:
    company_names.append(element.text if element.text else 'n/a')
    
company_description_elements = driver.find_elements("xpath", "//div[@class='card-body']")
for element in company_description_elements:
    company_description.append(element.text if element.text else 'n/a')
    
Data_elements = driver.find_elements("xpath", '//div[@class="card"]')
for element in Data_elements:
    data_id = element.get_attribute("data-id")
    if data_id:
        Data.append(site + 'detail?id=' + data_id)
        
df = pd.DataFrame({
    'Company Names': company_names,
    'Company Description': company_description,
    'Download Data': Data,
    'DLS website': ['Medusa Blog'] * len(company_names),
    'DLS link': ['http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsqyfry4ebnxlcbkccyd.onion/'] * len(company_names)
})

print(df)

driver.quit()
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_22820\328663817.py:8: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_22820\328663817.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_22820\328663817.py:14: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# %%
df
# Out:
#                                       Company Names  \
# 0                      Comisión Nacional de Valores
# 1                                  GAE Construction
# 2                                Tour Partner Group
# 3                           Concremat constructions
# 4                            Farmacias Los Hidalgos
# 5                                BilgeAdam Software
# 6                                       Fiduagraria
# 7                         Trabzonspor Football Club
# 8                      Leland Campbell LLP law firm
# 9                                    Amaszonas S.A.
# 10                                            SIGMA
# 11                               Al Tamimi Law Firm
# 12                              Wallick Communities
# 13                                            BAMSI
# 14                                       HostAfrica
# 15  Cooperativa de Ahorro y Crédito Ahorrocoop Ltda
# 16                    Sonda (Duplicate with update)
# 17            The Crown Princess Mary Cancer Centre
# 18                                    Polat Yol Yap
# 19                       Alto Calore Servizi S.p.A.
# 20                                      Bevan Group
# 21                             Magnolia Care Center
# 22                            Bentham & Holroyd Ltd
# 23                     WestcoastSmile Dental Studio
# 24                        Uniondale School District
# 25                                    Arandell Corp
# 26                                 Allimand, France
# 27                    Scantibodies Laboratory, Inc.
# 28                Atlantic International University
# 29                        Open University of Cyprus
# 30                                            Sonda
# 31                                  Gujarat Mineral
# 32                                   Atlas Security
# 33           National Institute of Ocean Technology
# 34                              Bishop Luffa School
# 35                      National Business Furniture
# 36                                 Garbarino SAICeI
# 37                       Minneapolis Public Schools
# 38                The Institute of Space Technology
# 39                         Kenya Airports Authority
# 40                                   Bank of Africa
# 41                    Moose, Martin, Haynes & Lundy
# 42                       RAYAB Consulting Engineers
# 43              International Center of Photography
# 44                        AP Emissions Technologies
# 45                            Foamtec International
# 46                             PetroChina Indonesia
# 47                             Tonga Communications
# 48                 Diethelm Keller Aviation Pte Ltd
# 49                             Eureka Casino Resort
# 50                                            EnCom
# 51                                      PFA Systems
# 52                                      Elim Clinic
# 53                                  Elektro Richter
# 54                                  European Window
# 55                                EightPixelsSquare
# 56                                          Aglobis
# 57                                   Integerity Tax
# 58                       Grace Church International
#
#                                   Company Description  \
# 0   Regulatory agency in charge of authorizing IPO...
# 1   Website: https://gae-construction.co.uk/ GAE C...
# 2   Tour Partner Group is a holding company dealin...
# 3   Founded in 1972 and headquartered in Rio de Ja...
# 4   Farmacias Los Hidalgos is a health, wellness a...
# 5   BilgeAdam operates as one of the subsidiaries ...
# 6   Fiduagraria is a joint-stock company of a mixe...
# 7   Trabzonspor Kulübü ( German Sportklub Trabzon ...
# 8   Leland Campbell LLP is the largest law firm in...
# 9   Lnea Aérea Amaszonas S.A. ("Amaszonas") is a B...
# 10  SIGMA is a company located at 4915 Ambroise La...
# 11  Founded by Essam Al Tamimi in 1989, Al Tamimi ...
# 12  Wallick Communities provides property manageme...
# 13  BAMSI is a private, non-profit social services...
# 14  HostAfrica was founded in 2015 in Cape Town wi...
# 15  Cooperativa de Ahorro y Crédito Ahorrocoop Ltd...
# 16  Sonda, This is a Chilean multinational IT comp...
# 17  Westmead's service has been operating since 19...
# 18  Polat Yol Yap is a company that operates in th...
# 19  Alto Calore Servizi S.p.A., abbreviated ACS, w...
# 20  Founded in 1976, the Bevan Group company is a ...
# 21  Magnolia Care Center ~ A Veteran's Home~ is a ...
# 22  Bentham & Holroyd Ltd is an engineering firm f...
# 23  WestcoastSmile Kitsilano Dental Studio was est...
# 24  Uniondale School District is a district locate...
# 25  Founded in 1922, Arandell provides premedia, c...
# 26  Founded in 1850 in France, Allimand is a world...
# 27  Scantibodies Laboratory, Inc. (SLI) founded in...
# 28  Atlantic International University, V. ("AIA") ...
# 29  The Open University of Cyprus (OUC) was establ...
# 30  SONDA, a Chilean multinational IT company head...
# 31  Gujarat Mineral Development Corporation Limite...
# 32  Atlas Security is the leading armed response c...
# 33  The National Institute of Ocean Technology (NI...
# 34  Bishop Luffa School, named after a former Bish...
# 35  National Business Furniture (NBF), founded in ...
# 36  Garbarino, headquartered in Argentina, founded...
# 37  Minneapolis Public Schools (MPS) or Special Sc...
# 38  The Institute of Space Technology (also known ...
# 39  Kenya Airports Authority (KAA) is the owner an...
# 40  * We have shared file tree. Direct download li...
# 41  For years, Moose, Martin, Haynes & Lundy, P.A....
# 42  RAYAB Consulting Engineers Company was founded...
# 43  New York, 374 Employees. The International Cen...
# 44  Automotive Parts · North Carolina, United Stat...
# 45  The best of East and West - that is the streng...
# 46  PetroChina Indonesia is a company that operate...
# 47  Tonga Communications Corporation is a governme...
# 48  Diethelm Keller Aviation Pte Ltd (DKA), a glob...
# 49  Eureka Casinos was founded by the Lee family i...
# 50  Founded in 2001, EnCom Inc is a specialty prod...
# 51  PFA SYSTEMS, Inc. was started over thirty year...
# 52  Elim Clinic is a professional treatment centre...
# 53  Elektro Richter is a company that operates in ...
# 54  European Window Company is an Australian leade...
# 55  Founded in December 2012 and based in Derby, U...
# 56  Resistance shall not prevent us from fulfillin...
# 57  Small business accounting, tax preparation, bo...
# 58  We Believe the Bible is God's supreme authorit...
#
#                                         Download Data  DLS website  \
# 0   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 1   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 2   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 3   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 4   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 5   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 6   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 7   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 8   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 9   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 10  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 11  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 12  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 13  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 14  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 15  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 16  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 17  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 18  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 19  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 20  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 21  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 22  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 23  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 24  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 25  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 26  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 27  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 28  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 29  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 30  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 31  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 32  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 33  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 34  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 35  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 36  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 37  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 38  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 39  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 40  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 41  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 42  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 43  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 44  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 45  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 46  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 47  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 48  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 49  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 50  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 51  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 52  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 53  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 54  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 55  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 56  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 57  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
# 58  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...  Medusa Blog
#
#                                              DLS link
# 0   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 1   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 2   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 3   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 4   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 5   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 6   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 7   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 8   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 9   http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 10  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 11  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 12  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 13  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 14  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 15  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 16  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 17  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 18  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 19  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 20  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 21  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 22  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 23  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 24  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 25  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 26  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 27  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 28  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 29  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 30  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 31  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 32  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 33  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 34  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 35  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 36  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 37  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 38  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 39  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 40  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 41  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 42  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 43  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 44  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 45  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 46  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 47  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 48  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 49  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 50  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 51  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 52  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 53  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 54  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 55  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 56  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 57  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
# 58  http://medusaxko7jxtrojdkxo66j7ck4q5tgktf7uqsq...
