# %%
from selenium import webdriver
import pandas as pd
import time

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://lockbitapt2d73krlbewgv27tquljgxr33xbwwsp6rkyieto7u4ncead.onion'
driver.get(site)

# Wait for 10 seconds
time.sleep(10)

# create empty lists to store the data
company_names = []
company_description=[]
company_websites = []
Data = []

# extract the data from the current page
name_elements = driver.find_elements("xpath", '//div[@class="post-title"]')
for element in name_elements:
    company_names.append(element.text if element.text else 'n/a')
    
company_description_elements = driver.find_elements("xpath", "//div[@class='post-block-text']")
for element in company_description_elements:
    company_description.append(element.text if element.text else 'n/a')
    
websites_elements = driver.find_elements("xpath", '//div[@class="post-title"]')
for element in websites_elements:
    name = element.text if element.text else 'n/a'
    company_websites.append('https://' + name)

Data_elements = driver.find_elements("xpath", "//div[contains(@class, 'post-block') and contains(@class, 'good') or contains(@class, 'bad')]")
for element in Data_elements:
    onclick_value = element.get_attribute("onclick")
    url = onclick_value.split("go('")[1].split("')")[0]
    Data.append(site + url)    
        
# create a dataframe with the extracted data
df = pd.DataFrame({
    'Company Names': company_names,
    'Company Description': company_description,
    'company_websites': company_websites,
    'Download Data': Data,
    'DLS website': ['Lockbit'] * len(company_names),
    'DLS link': ['http://lockbitapt2d73krlbewgv27tquljgxr33xbwwsp6rkyieto7u4ncead.onion'] * len(company_names)
})

print(df)

#driver.quit()
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_29248\35658157.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_29248\35658157.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_29248\35658157.py:13: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                   Company Names  \
# 0                      TSMC.com
# 1           oneexchangecorp.com
# 2                      snjb.net
# 3                      snjb.net
# 4          bancodevenezuela.com
# ..                          ...
# 816           bosco-avocats.com
# ...

# %%
from selenium import webdriver
import time

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://royal4ezp7xrbakkus3oofjw6gszrohpodmdnfbe5e4w3og5sm7vb3qd.onion/'
driver.get(site)

# Function to scroll down until the end of the page
def scroll_to_bottom(driver):
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Adjust the sleep time as needed
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# Function to scroll up to the top of the page with a smooth scroll
def scroll_to_top(driver):
    current_y_offset = driver.execute_script("return window.pageYOffset;")
    while current_y_offset > 0:
        current_y_offset -= 100  # Adjust the scroll step as needed
        if current_y_offset < 0:
            current_y_offset = 0
        driver.execute_script(f"window.scrollTo(0, {current_y_offset});")
        time.sleep(0.0001)  # Adjust the sleep time to control the scroll speed


scroll_to_bottom(driver)


scroll_to_top(driver)
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3025206823.py:6: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3025206823.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3025206823.py:12: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# %%
company_names = []
company_description=[]

Data = []

# extract the data from the current page
name_elements = driver.find_elements("xpath", '//div[@class="card"]/h2')
for element in name_elements:
    company_names.append(element.text if element.text else 'n/a')
    
card_elements = driver.find_elements("xpath", '//div[@class="card"]')

# Loop through each <div> element and find the <p> elements within it
for card_element in card_elements:
    # Find all the <p> elements within the current <div class="card">
    p_elements = card_element.find_elements("xpath", './main/p')

    # Loop through each <p> element and append its text to the company_description list
    for p_element in p_elements:
        company_description.append(p_element.text if p_element.text else 'n/a')
        
Data_elements = driver.find_elements("xpath", '//ol')
for element in Data_elements:
    Data.append(element.get_attribute("href") if element.get_attribute("href") else 'n/a')

# %%
        
Data_elements = driver.find_elements("xpath", '//ol')
for element in Data_elements:
    Data.append(element.get_attribute("href") if element.get_attribute("href") else 'n/a')

# %%
Data_elements = driver.find_elements("xpath", '//ol')

for element in Data_elements:
    # Find the first <a> tag within the first <li> tag inside the <ol> element
    anchor_element = element.find_elements("xpath", './li[1]/a')

    # Check if the anchor_element exists and has the 'href' attribute
    if anchor_element:
        href_value = anchor_element[0].get_attribute("href")
        Data.append(href_value if href_value else 'n/a')
    else:
        Data.append('n/a')

# %%
len(Data)
# Out:
# 386

# %%
overall_datas = driver.find_elements("xpath", '//div[@class="post active"]')

company_name= overall_data.find_element("xpath", '//div[@class="card"]/h2').text
company_description=overall_data.find_element("xpath", '//div[@class="card"]/main/p').text
Data=overall_data.find_element("xpath", '//div[@class="info"]').get("href")

# %%
overall_data
# Out:
# '11\nJune\n2023\n100%\nLink #1\nTachi-S Engineering USA\nGlobal Seat System Creator\nAt Tachi-S, we help automotive manufacturers launch their cars, trucks and SUVs by designing, developing, testing and manufacturing high-quality automotive seats that are functional, safe, stylish and most importantly comfortable.\nEach year, Tachi-S delivers over 3 million complete automotive seats and over 4 million seat components to the global automotive market. Our success is based on being responsive, flexible and easy to work with to help assure that every automotive seating program is completed on-time, on-budget and delivered with high quality. That’s how we do business…and that’s why we have been a continuously selected company in the automotive industry.\nWebsite\nLink\nRevenue\n$28.9M\nEmployees\n50'

# %%
from selenium import webdriver
import time
import pandas as pd

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://royal4ezp7xrbakkus3oofjw6gszrohpodmdnfbe5e4w3og5sm7vb3qd.onion/'
driver.get(site)

# Function to scroll down until the end of the page
def scroll_to_bottom(driver):
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Adjust the sleep time as needed
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# Function to scroll up to the top of the page with a smooth scroll
def scroll_to_top(driver):
    current_y_offset = driver.execute_script("return window.pageYOffset;")
    while current_y_offset > 0:
        current_y_offset -= 100  # Adjust the scroll step as needed
        if current_y_offset < 0:
            current_y_offset = 0
        driver.execute_script(f"window.scrollTo(0, {current_y_offset});")
        time.sleep(0.0001)  # Adjust the sleep time to control the scroll speed


scroll_to_bottom(driver)
scroll_to_top(driver)

# Find all "overall_data" elements using the specified xpath
overall_datas = driver.find_elements("xpath", '//div[@class="post active"]')

# Initialize an empty list to store the data
data_list = []

# Loop through each "overall_data" element
for overall_data in overall_datas:
    # Extract the company_name, company_description, and Data
    company_name = overall_data.find_element("xpath", './/div[@class="card"]/h2').text
    
    # Use list comprehension to get all <p> elements and their text within "company_description"
    company_description_elements = overall_data.find_elements("xpath", './/div[@class="card"]/main/p')
    company_description = "\n".join([element.text for element in company_description_elements])
    
    data = overall_data.find_element("xpath", './/div[@class="info"]').get_attribute("href")

    # Append the data as a dictionary to the list
    data_list.append({
        'company_name': company_name,
        'company_description': company_description,
        'Data': data
    })

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data_list)

# Print the DataFrame (optional)
print(df)
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_6660\506443835.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_6660\506443835.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_6660\506443835.py:13: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                                          company_name  \
# 0                            Braintree Public Schools
# 1                             Tachi-S Engineering USA
# 2                           PENNCREST School District
# 3                                                Volt
# ...

# %%
import time
import pandas as pd

# %%
Data_elements = driver.find_elements("xpath", '//ol')

# Variable to keep track of the total number of //ol elements
total_ol_count = len(Data_elements)

# List to store the scraped data
Data = []

for element in Data_elements:
    # Check if the element has //ol/li/a
    li_elements = element.find_elements("xpath", './li/a')
    
    if li_elements:
        # If //ol/li/a exists, scrape the href attribute
        Data.append(li_elements[0].get_attribute("href") if li_elements[0].get_attribute("href") else 'n/a')
    else:
        # If only //ol exists, append 'n/a'
        Data.append('n/a')

# Check if any direct //ol elements were not processed, and add 'n/a' for them
if len(Data) < total_ol_count:
    remaining_ol_count = total_ol_count - len(Data)
    Data.extend(['n/a'] * remaining_ol_count)

# %%
Data
# Out:
# ['n/a',
#  'http://72u5vd67xdff354hhge6wjuvsixxwo3c6bvrdlqstgmjfptpbzwrsmad.onion/Tachies.7z',
#  'n/a',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/VOLT/vrt2gyhu213/VOLT.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/AMERIFORGE/mknjh3gts/AMERIFORGE.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/MITUTOYO/gyrf2314vgdyu/MITUTOYO.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/SWSGROUP/mjkdqw21341js/SWSGROUP.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/DIRECTVIZ/bgh7bhj66sda/DIRECTVIZ.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/PRECISION/lp7nhf678fcvsd/PRECISION.PART1.zip',
#  'http://k6s24pz55gtvtzzpg4riv7zb74vts425bl42zrpmice5ud3a65itj6ad.onion/SOVITRAT/hygt3djks334/SOVITRAT.PART1.zip',
# ...

# %%
from selenium import webdriver
import time
import pandas as pd

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://royal4ezp7xrbakkus3oofjw6gszrohpodmdnfbe5e4w3og5sm7vb3qd.onion/'
driver.get(site)

# Function to scroll down until the end of the page
def scroll_to_bottom(driver):
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Adjust the sleep time as needed
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# Function to scroll up to the top of the page with a smooth scroll
def scroll_to_top(driver):
    current_y_offset = driver.execute_script("return window.pageYOffset;")
    while current_y_offset > 0:
        current_y_offset -= 100  # Adjust the scroll step as needed
        if current_y_offset < 0:
            current_y_offset = 0
        driver.execute_script(f"window.scrollTo(0, {current_y_offset});")
        time.sleep(0.0001)  # Adjust the sleep time to control the scroll speed


scroll_to_bottom(driver)
scroll_to_top(driver)

# Find all "overall_data" elements using the specified xpath
overall_datas = driver.find_elements("xpath", '//div[@class="post active"]')

# Initialize an empty list to store the data
data_list = []

# Loop through each "overall_data" element
for overall_data in overall_datas:
    # Extract the company_name, company_description, and Data
    company_name = overall_data.find_element("xpath", './/div[@class="card"]/h2').text
    
    # Use list comprehension to get all <p> elements and their text within "company_description"
    company_description_elements = overall_data.find_elements("xpath", './/div[@class="card"]/main/p')
    company_description = "\n".join([element.text for element in company_description_elements])
    
    # Find all "ol" elements
    data_elements = overall_data.find_elements("xpath", './/ol')

    # Variable to keep track of the total number of "ol" elements
    total_ol_count = len(data_elements)

    # List to store the scraped data
    data = []

    for element in data_elements:
        # Check if the element has "li/a" elements
        li_elements = element.find_elements("xpath", './li/a')

        if li_elements:
            # If "li/a" elements exist, scrape the href attribute
            data.append(li_elements[0].get_attribute("href") if li_elements[0].get_attribute("href") else 'n/a')
        else:
            # If only "ol" elements exist, append 'n/a'
            data.append('n/a')

    # Check if any direct "ol" elements were not processed, and add 'n/a' for them
    if len(data) < total_ol_count:
        remaining_ol_count = total_ol_count - len(data)
        data.extend(['n/a'] * remaining_ol_count)
    
    # Append the data as a dictionary to the list
    data_list.append({
        'company_name': company_name,
        'company_description': company_description,
        'Data': data
    })

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data_list)

# Print the DataFrame (optional)
print(df)

driver.quit()
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3590771355.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3590771355.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_13588\3590771355.py:13: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                            company_name  \
# 0              Braintree Public Schools
# 1               Tachi-S Engineering USA
# 2             PENNCREST School District
# 3                                  Volt
# 4                          AFG Holdings
# ...

# %%
import selenium

print(selenium.__version__)
# Out:
# 4.8.2
