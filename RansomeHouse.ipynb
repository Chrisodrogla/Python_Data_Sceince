# %%
from selenium import webdriver
import pandas as pd
import time

# set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# navigate to the website
site = 'http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp744qhx6gjmxbuo2yid.onion/'
driver.get(site)
time.sleep(5)
company_names = []

Data = []

name_elements = driver.find_elements("xpath", '//div[@class="cls_recordTop"]/p')
for element in name_elements:
    company_names.append(element.get_attribute("innerText") if element.get_attribute("innerText") else 'n/a')

Data_elements = driver.find_elements("xpath", '//div[@class="cls_record"]/a')
for element in Data_elements:
    Data.append(element.get_attribute("href") if element.get_attribute("href") else 'n/a')
    
# create a dataframe with the extracted data
df = pd.DataFrame({
    'Company Names': company_names,
    'Download Data': Data
})

print(df)
driver.quit()
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_19956\1900558417.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_19956\1900558417.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_19956\1900558417.py:13: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                                Company Names  \
# 0                          Wison Engineering
# 1                               Prada Gayoso
# 2                    Roberto Verino Difusion
# 3                 Mission Community Hospital
# 4                                AvidXchange
# 5                       100X and ALL Clients
# 6              Albany ENT & Allergy Services
# 7                         Tranztec Solutions
# 8      OMT Officine Meccaniche Torino S.p.A.
# 9                   Aero Engine Solution INC
# 10              Hospital Clinic de Barcelona
# 11                             AV Industries
# 12                    Tanbridge House School
# 13                                Cospec Srl
# 14                             Comune Taggia
# 15                           Design CATAPULT
# 16                           Indonesia Power
# 17                        Faraday Technology
# 18                         St. Kitts & Nevis
# 19           Delaware Life Insurance Company
# 20             E&S Heating & Ventilation Ltd
# 21                               Audio Video
# 22                  AESCULAPIUS Farmaceutici
# 23                      Hospital Service SpA
# 24                           Jeffries Morris
# 25                                  The DGCX
# 26                                   Holovis
# 27                   Trans Maldivian Airways
# 28                  IMI Hydronic Engineering
# 29                           Strem Chemicals
# 30                                   Keralty
# 31                       Republic of Vanuatu
# 32                       BRYCON Construction
# 33                             SMB Solutions
# 34                       Severn Glocon Group
# 35                          ADATA Technology
# 36                 Carmen Copper Corporation
# 37                         Ipca Laboratories
# 38                         8 Italy Districts
# 39                  Fairfax - Crum & Forster
# 40                               Summit Care
# 41               Advanced Micro Devices, Inc
# 42                     SHOPRITE HOLDINGS LTD
# 43       AHS Aviation Handling Services GmbH
# 44                       Dellner Couplers AB
# 45                    Jefferson Credit Union
# 46  Saskatchewan Liquor and Gaming Authority
#
#                                         Download Data
# 0   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 1   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 2   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 3   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 4   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 5   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 6   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 7   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 8   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 9   http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 10  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 11  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 12  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 13  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 14  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 15  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 16  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 17  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 18  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 19  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 20  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 21  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 22  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 23  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 24  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 25  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 26  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 27  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 28  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 29  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 30  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 31  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 32  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 33  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 34  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 35  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 36  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 37  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 38  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 39  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 40  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 41  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 42  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 43  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 44  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 45  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
# 46  http://zohlm7ahjwegcedoz7lrdrti7bvpofymcayotp7...
