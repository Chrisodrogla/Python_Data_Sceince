# %%
from selenium import webdriver
import time
import pandas as pd
# Set up TOR and the TOR browser
tor_proxy = "socks5://127.0.0.1:9150"
profile = webdriver.FirefoxProfile()
profile.set_preference('network.proxy.type', 1)
profile.set_preference('network.proxy.socks', '127.0.0.1')
profile.set_preference('network.proxy.socks_port', 9150)
profile.set_preference('network.proxy.socks_remote_dns', True)
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')

# Navigate to the website
site = 'http://sbc2zv2qnz5vubwtx3aobfpkeao6l4igjegm3xx7tk5suqhjkp5jxtqd.onion/'
driver.get(site)

company_names = []
Data = [] 

while True:

    
    name_elements = driver.find_elements("xpath", '//div[@class="box post-box"]/h2/a')
    for element in name_elements:
        company_names.append(element.get_attribute("innerText") if element.get_attribute("innerText") else 'n/a')

    Data_elements = driver.find_elements("xpath", '//div[@class="box post-box"]/h2/a')
    for element in Data_elements:
        Data.append(element.get_attribute("href") if element.get_attribute("href") else 'n/a') 


    pagination_element = driver.find_elements("xpath", '//i[@class="icon icon-arrow-right"]')

    if not pagination_element:
        break  


    driver.execute_script("arguments[0].click();", pagination_element[1])


    time.sleep(5)


df = pd.DataFrame({
    'Company Names': company_names,
    'Download Data': Data,
    'DLS website': ['D#NUTS'] * len(company_names),
    'DLS link': ['http://sbc2zv2qnz5vubwtx3aobfpkeao6l4igjegm3xx7tk5suqhjkp5jxtqd.onion/'] * len(company_names)
})

print(df)

driver.quit()
# Out:
# C:\Users\calgo\AppData\Local\Temp\ipykernel_31080\1065859434.py:6: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = webdriver.FirefoxProfile()
# C:\Users\calgo\AppData\Local\Temp\ipykernel_31080\1065859434.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
# C:\Users\calgo\AppData\Local\Temp\ipykernel_31080\1065859434.py:12: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(firefox_profile=profile, executable_path='/path/to/geckodriver')
#                     Company Names  \
# 0                    Peroni Pompe
# 1       Jacklyn Dawson Solicitors
# 2        The Travel Network Group
# 3                   UnitedLex.com
# 4         Nabtesco Motion Control
# 5     Montgomery General Hospital
# 6             Garden Hotel NARITA
# 7            JANUS Research Group
# 8   Southwest Healthcare Services
# 9                    Evo exhibits
# 10    Health Care Solutions Group
# 11                Sheppard Robson
# 12        PlanET Biogas Solutions
# 13                         CMZ UK
# 14                          Sando
# 15                    Enso Detego
#
#                                         Download Data DLS website  \
# 0   http://sbc2zv2qnz5vubwtx3aobfpkeao6l4igjegm3xx...      D#NUTS
# 1   http://sbc2zv2qnz5vubwtx3aobfpkeao6l4igjegm3xx...      D#NUTS
